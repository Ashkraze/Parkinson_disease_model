# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/parkinsons-disease-dataset-analysis/parkinsons_disease_data.csv

# %%
df1 = pd.read_csv("/kaggle/input/parkinsons-disease-dataset-analysis/parkinsons_disease_data.csv")

# %%
df1
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          3058   85       0          3               1  19.619878        0
# 1          3059   75       0          0               2  16.247339        1
# 2          3060   70       1          0               0  15.368239        0
# 3          3061   52       0          0               0  15.454557        0
# 4          3062   87       0          0               1  18.616042        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2100       5158   87       1          0               2  38.483841        0
# 2101       5159   67       0          0               1  33.694396        1
# 2102       5160   65       0          0               2  22.829631        0
# 2103       5161   61       1          0               0  16.871030        1
# 2104       5162   56       0          0               2  16.569934        0
#
# ...

# %% [markdown]
# # Dataset Info

# %%
df1.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'AlcoholConsumption', 'PhysicalActivity', 'DietQuality',
#        'SleepQuality', 'FamilyHistoryParkinsons', 'TraumaticBrainInjury',
#        'Hypertension', 'Diabetes', 'Depression', 'Stroke', 'SystolicBP',
#        'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
#        'CholesterolTriglycerides', 'UPDRS', 'MoCA', 'FunctionalAssessment',
#        'Tremor', 'Rigidity', 'Bradykinesia', 'PosturalInstability',
#        'SpeechProblems', 'SleepDisorders', 'Constipation', 'Diagnosis',
#        'DoctorInCharge'],
#       dtype='object')

# %%
#dropping col as it is of no significance
df1.drop(columns = {'DoctorInCharge','PatientID'}, inplace =True)

# %%
#null values in the dataset
df1.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Ethnicity                   0
# EducationLevel              0
# BMI                         0
# Smoking                     0
# AlcoholConsumption          0
# PhysicalActivity            0
# DietQuality                 0
# SleepQuality                0
# FamilyHistoryParkinsons     0
# TraumaticBrainInjury        0
# Hypertension                0
# Diabetes                    0
# Depression                  0
# Stroke                      0
# SystolicBP                  0
# DiastolicBP                 0
# CholesterolTotal            0
# CholesterolLDL              0
# CholesterolHDL              0
# CholesterolTriglycerides    0
# UPDRS                       0
# MoCA                        0
# FunctionalAssessment        0
# Tremor                      0
# Rigidity                    0
# Bradykinesia                0
# PosturalInstability         0
# SpeechProblems              0
# SleepDisorders              0
# ...

# %%
df1.columns
# Out:
# Index(['Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI', 'Smoking',
#        'AlcoholConsumption', 'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'FamilyHistoryParkinsons', 'TraumaticBrainInjury', 'Hypertension',
#        'Diabetes', 'Depression', 'Stroke', 'SystolicBP', 'DiastolicBP',
#        'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
#        'CholesterolTriglycerides', 'UPDRS', 'MoCA', 'FunctionalAssessment',
#        'Tremor', 'Rigidity', 'Bradykinesia', 'PosturalInstability',
#        'SpeechProblems', 'SleepDisorders', 'Constipation', 'Diagnosis'],
#       dtype='object')

# %%
#All column dictionary
col_dict = {'PatientID':'patient_id', 'Age':'age', 'Gender':'gender', 'Ethnicity':'ethnicity', 'EducationLevel':'edlevel',
                      'BMI':'bmi','Smoking':'smoking', 'AlcoholConsumption':'alc_cons', 'PhysicalActivity':'phy_activity', 
                      'DietQuality':'diet_qual','SleepQuality':'sleep_qual', 'FamilyHistoryParkinsons':'fam_park', 
                      'TraumaticBrainInjury':'trauma_brain','Hypertension':'hyperext', 'Diabetes':'diabates',
                      'Depression':'depression','Stroke':'stroke','SystolicBP':'systolicbp','DiastolicBP':'diastolicbp', 
                      'CholesterolTotal':'chole_total', 'CholesterolLDL':'chole_ldl', 'CholesterolHDL':'chole_hdl',
                      'CholesterolTriglycerides':'chole_tri', 'UPDRS':'updrs', 'MoCA':'moca', 'FunctionalAssessment':'func_ass',
                      'Tremor':'tremor', 'Rigidity':'rigidity', 'Bradykinesia':'bradykinesia', 'PosturalInstability':'post_instab',
                      'SpeechProblems':'speech_prob', 'SleepDisorders':'sleep_dis', 'Constipation':'cons', 'Diagnosis':'diagnosis'}

# %%
df1.rename(columns = col_dict,inplace =True)

# %%
cat_cols = ['gender', 'ethnicity', 'edlevel','smoking','fam_park','trauma_brain','hyperext','diabates','depression','stroke',
            'tremor','rigidity','bradykinesia','post_instab','speech_prob','sleep_dis','cons','diagnosis']

# %%
#categorical columns and their value counts
for col in cat_cols:
    print(col,dict(df1[col].value_counts()))
# Out:
# gender {0: 1068, 1: 1037}
# ethnicity {0: 1270, 1: 425, 3: 213, 2: 197}
# edlevel {1: 840, 2: 656, 0: 388, 3: 221}
# smoking {0: 1481, 1: 624}
# fam_park {0: 1798, 1: 307}
# trauma_brain {0: 1881, 1: 224}
# hyperext {0: 1798, 1: 307}
# diabates {0: 1793, 1: 312}
# depression {0: 1673, 1: 432}
# stroke {0: 2002, 1: 103}
# tremor {0: 1196, 1: 909}
# rigidity {0: 1573, 1: 532}
# bradykinesia {0: 1668, 1: 437}
# post_instab {0: 1813, 1: 292}
# speech_prob {0: 1484, 1: 621}
# sleep_dis {0: 1589, 1: 516}
# cons {0: 1480, 1: 625}
# diagnosis {1: 1304, 0: 801}

# %%
#numerical categorical columns
num_cols = [i for i in df1.columns if i not in cat_cols]

# %%
#numerical columns and range of the columns
for col in num_cols:
    print(col,list((int(max(df1[col])),int(min(df1[col])))))
# Out:
# age [89, 50]
# bmi [39, 15]
# alc_cons [19, 0]
# phy_activity [9, 0]
# diet_qual [9, 0]
# sleep_qual [9, 4]
# systolicbp [179, 90]
# diastolicbp [119, 60]
# chole_total [299, 150]
# chole_ldl [199, 50]
# chole_hdl [99, 20]
# chole_tri [399, 50]
# updrs [198, 0]
# moca [29, 0]
# func_ass [9, 0]

# %% [markdown]
# ### All columns are within range of criteria. Therefore no Outliers by range.

# %% [markdown]
# # EDA and Data Visualization

# %%
print("Data Description --\n")
print("Categorical columns in DataFrame are :",len(cat_cols),"\n" "Numerical columns in DataFrame are :", len(num_cols))
# Out:
# Data Description --
#
# Categorical columns in DataFrame are : 18
# Numerical columns in DataFrame are : 15

# %%
#countplot of all object type variables

plt.figure(figsize = (10,28))

for i in range(len(cat_cols)):
    plt.subplot(9,2,i+1)
    sns.countplot(df1,x = df1[cat_cols[i]])
    plt.title(f"Countplot of {cat_cols[i]}")

plt.tight_layout()
plt.show()

# %%
columns =["smoking","fam_park","trauma_brain","hyperext","diabates","depression","stroke","rigidity","bradykinesia","post_instab","sleep_dis", "cons"]

#Inferences
print(f"1. Data in {columns} are biased \n")
print(f"2. Biased columns may directly affect the target variable and can be verified using DT,Bagging Boosting Models, SV, KNN")
# Out:
# 1. Data in ['smoking', 'fam_park', 'trauma_brain', 'hyperext', 'diabates', 'depression', 'stroke', 'rigidity', 'bradykinesia', 'post_instab', 'sleep_dis', 'cons'] are biased
#
# 2. Biased columns may directly affect the target variable and can be verified using DT,Bagging Boosting Models, SV, KNN

# %%
#Changing categorical cols to oject type

for i in cat_cols:
    df1[i] = df1[i].astype("object")

# %%
#histplots of int type vars

plt.figure(figsize = (10,10))

for i in range(len(df1.select_dtypes(exclude= "object").columns)):
    plt.subplot(4,4,i+1)
    sns.histplot(df1, x = df1[df1.select_dtypes(exclude= "object").columns[i]])
    plt.title(f"Histplot of {df1.select_dtypes(exclude = 'object').columns[i]}")

plt.tight_layout()
plt.plot()
# Out:
# []

# %%
#histplot of int type variable with respect to infected
plt.figure(figsize = (10,8))
for i in range(len(df1.select_dtypes(exclude = 'object').columns)):
    plt.subplot(4,4,i+1)
    sns.histplot(df1,x = df1.select_dtypes(exclude = 'object').columns[i], hue = 'diagnosis',legend=False)
    plt.title(f"Histplot of {df1.select_dtypes(exclude = 'object').columns[i]}")

plt.tight_layout()
plt.show()

# %%
print(f"No of rows in (diagnosis = 1) :",len(df1[df1["diagnosis"]==1]),"and No of rows in (diagnosis = 0) :",len(df1[df1["diagnosis"]==0]))
# Out:
# No of rows in (diagnosis = 1) : 1304 and No of rows in (diagnosis = 0) : 801

# %%
#creating a Dataframe with mean of all numeric columns wrt target variables (diagnosis)
df_mean = pd.DataFrame([list(df1[df1["diagnosis"]==0].select_dtypes(exclude = "object").mean()),list(df1[df1["diagnosis"]==1].select_dtypes(exclude = "object").mean())],columns = [i for i in df1[df1["diagnosis"]==0].select_dtypes(exclude = "object").columns])

# %%
df_mean['diagnosis'] = ["False","True"]
df_mean
# Out:
#          age        bmi   alc_cons  phy_activity  diet_qual  sleep_qual  \
# 0  68.635456  26.932601   9.774184      4.968954   4.997137    7.093457
# 1  70.195552  27.379577  10.203948      5.045987   4.861158    6.937167
#
#    systolicbp  diastolicbp  chole_total   chole_ldl  chole_hdl   chole_tri  \
# 0  133.868914    90.882647   227.917357  125.333531  60.255434  220.911515
# 1  133.628067    89.861196   226.211859  126.648069  59.310957  224.186832
#
#         updrs       moca  func_ass diagnosis
# 0   72.683695  17.002809  5.831890     False
# 1  119.064114  13.921994  4.472364      True

# %%
#Bar plots of all Numeric columns [diagnosis = 0 vs diagnosis = 1]

plt.figure(figsize = (10,8))

for i in range(len(df_mean.select_dtypes(exclude = "object").columns)):
    plt.subplot(5,3,i+1)
    sns.barplot(df_mean,y = df_mean.select_dtypes(exclude = "object").columns[i], x = 'diagnosis')
    #plt.title("Histplot of",i)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### UPDRS: Unified Parkinson's Disease Rating Scale score, ranging from 0 to 199. Higher scores indicate greater severity of the disease.
# ##### As the level of updrs rise above 75 the risk of diagnosis increases manyfold
#
# #### FunctionalAssessment: Functional assessment score, ranging from 0 to 10. Lower scores indicate greater impairment.
# ##### As the level of func_ass fall below 5.0 the risk of diagnosis increases

# %%
#countplot of target variable
sns.countplot(x =df1['diagnosis'])
plt.title("Countplot of Diagnosis")
# Out:
# Text(0.5, 1.0, 'Countplot of Diagnosis')

# %%
#Level of UPDRS and Functional Assessment have a direct impact on Diagnosis.

# %%
df1
# Out:
#       age gender ethnicity edlevel        bmi smoking   alc_cons  \
# 0      85      0         3       1  19.619878       0   5.108241
# 1      75      0         0       2  16.247339       1   6.027648
# 2      70      1         0       0  15.368239       0   2.242135
# 3      52      0         0       0  15.454557       0   5.997788
# 4      87      0         0       1  18.616042       0   9.775243
# ...   ...    ...       ...     ...        ...     ...        ...
# 2100   87      1         0       2  38.483841       0  12.674393
# 2101   67      0         0       1  33.694396       1   0.977018
# 2102   65      0         0       2  22.829631       0   6.152286
# 2103   61      1         0       0  16.871030       1   0.292094
# 2104   56      0         0       2  16.569934       0   1.985084
#
#       phy_activity  diet_qual  sleep_qual  ...       moca  func_ass tremor  \
# 0         1.380660   3.893969    9.283194  ...  29.181289  1.572427      1
# ...

# %% [markdown]
# # Null Value Treatment

# %%
#visual representation of missing values in the dataset
plt.figure(figsize=(8,3))
sns.heatmap(df1.isnull(), cmap = 'plasma')
plt.show()

# %%
# Duplicates in the dataset
df1.duplicated().sum()
# Out:
# 0

# %%
#removing the test_data from the training dataset
df1.drop(index = df1[df1['diagnosis'].isnull()].index, inplace=True)

# %%
#function to find count and percentage null values in the dataset
def null_values(dfx):

    null_val_dict = {}
    for i in range(len(dfx.isnull().sum())):
        null_val_dict[dfx.columns[i]] = dfx.isnull().sum()[i]
    
    keys_to_del = []
    
    for i in null_val_dict.keys():
        if null_val_dict[i] == 0:
            keys_to_del.append(i)
    
    for i in keys_to_del:
        null_val_dict.pop(i)
    
    df_null= pd.DataFrame({"col_name":null_val_dict.keys(),"null_values":null_val_dict.values(),'percent_null':[f"{round((i/len(dfx))*100,0)}%" for i in null_val_dict.values()]})
    
    return df_null

# %%
null_values(df1)
# Out:
# Empty DataFrame
# Columns: [col_name, null_values, percent_null]
# Index: []

# %% [markdown]
# # Outlier Treatment

# %%
def outliers(dfx,target):

    df_num=dfx.select_dtypes(exclude = 'object')
    
    list2=list(df1.columns).pop(list(df1.columns).index(target))
    list1= []
    
    for i in df_num.columns:
        q1 = np.nanquantile(dfx[i],0.25)
        q3 = np.nanquantile(dfx[i],0.75)
        iqr = q3-q1
        upper_lim = q1 - 1.5*(iqr)
        lower_lim = q3 + 1.5*(iqr)
        count = 0
    
        list1.append([i,len(dfx[(dfx[i]>lower_lim) | (dfx[i]<upper_lim)]),f"{round((len(dfx[(dfx[i]>lower_lim) | (dfx[i]<upper_lim)]))/len(df1),1)}%"])
    
    dfy = pd.DataFrame(list1,columns =['Columns','Outliers','Percent outliers'])    
    
    return dfy

# %%
#count of outliers and % of outliers in the data. 
outliers(df1,'diagnosis')
# Out:
#          Columns  Outliers Percent outliers
# 0            age         0             0.0%
# 1            bmi         0             0.0%
# 2       alc_cons         0             0.0%
# 3   phy_activity         0             0.0%
# 4      diet_qual         0             0.0%
# 5     sleep_qual         0             0.0%
# 6     systolicbp         0             0.0%
# 7    diastolicbp         0             0.0%
# 8    chole_total         0             0.0%
# 9      chole_ldl         0             0.0%
# 10     chole_hdl         0             0.0%
# 11     chole_tri         0             0.0%
# 12         updrs         0             0.0%
# 13          moca         0             0.0%
# 14      func_ass         0             0.0%

# %%
#function to find count and percentage null values in the dataset
def null_values(dfx):
    null_val_dict = {}
    for i in range(len(dfx.isnull().sum())):
        null_val_dict[dfx.columns[i]] = dfx.isnull().sum()[i]
    
    keys_to_del = []
    
    for i in null_val_dict.keys():
        if null_val_dict[i] == 0:
            keys_to_del.append(i)
        
    for i in keys_to_del:
        null_val_dict.pop(i)
    
    df_null= pd.DataFrame({"col_name":null_val_dict.keys(),"null_values":null_val_dict.values(),'percent_null':[f"{round((i/len(dfx))*100,0)}%" for i in null_val_dict.values()]})
    
    return df_null

# %%
#there are no null values in the dataset
null_values(df1)
# Out:
# Empty DataFrame
# Columns: [col_name, null_values, percent_null]
# Index: []

# %% [markdown]
# # Correlated Variables

# %%
x_corr = df1.drop(columns = ['diagnosis'])

# %%
sns.heatmap(x_corr.corr(),cmap = 'YlGnBu')
# Out:
# <Axes: >

# %%
#A function to find out highly corr vars and make a dict of the vars
def high_corr_fx(dfx,corr,target):
    df_corr= dfx.select_dtypes(exclude = "object")
    dict_corr= {}
    dict_pop=[]
    
    
    for i in df_corr.columns:
        dict_corr[i] = []
    
    
    for i in df_corr.columns:
        for j in df_corr.columns:
            if (i == j) or (i == target) or (j == target):
                pass
            else:
                if(abs(df1[i].corr(df1[j])) >= corr):
                    if((i not in dict_corr[j]) and (j not in dict_corr[i])):
                        dict_corr[i].append(j)
                    else:
                        pass
                else:
                    pass
    
    
    for i in dict_corr.keys():
        if (len(dict_corr[i]) == 0):
            dict_pop.append(i)
        else:
            pass
        
    for i in dict_pop:
        dict_corr.pop(i)
    
    
    return dict_corr

# %%
#columns with corr higher than 0.7
high_corr_fx(x_corr,0.6,'diagnosis')
# Out:
# {}

# %% [markdown]
# # Standardization

# %%
df_num = df1.select_dtypes(exclude = 'object')
df_cat = df1.select_dtypes(include = 'object')

# %%
from sklearn.preprocessing import StandardScaler as ss

scaled_df_num=pd.DataFrame(ss().fit_transform(df_num),columns = df_num.columns)
#scaled_df_num

# %%
#df_cat.dtypes
for i in df_cat.columns:
    df_cat[i] = df_cat[i].astype("int64")

# %%
df_scaled= pd.concat([scaled_df_num,df_cat],axis=1)
#df_scaled

# %%
y = df_scaled["diagnosis"]

# %%
df_scaled.drop(columns = ["diagnosis"],inplace =True)

# %% [markdown]
# # Smote Analysis

# %%
from sklearn.model_selection import train_test_split as tts
from imblearn.over_sampling import SMOTE

# %%
x_train, x_test, y_train, y_test = tts(df_scaled,y,test_size = 0.2,random_state = 20)

# %%
x_train_resampled, y_train_resampled = SMOTE().fit_resample(x_train, y_train)

# %%
#distribution of y after resampling 
plt.title(f"Distribution of target variable after SMOTE")
plt.pie(y_train_resampled.value_counts(),autopct='%.2f%%')
plt.show()

# %% [markdown]
# # Modelling

# %%
#Logistic,Decision, rANDOM FOREST,SVM
#Naive,k-Nearest,Kmeans clustering

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier


from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree Classifier': DecisionTreeClassifier(),
    'Random Forest Classifier':RandomForestClassifier()
         }

# %%
# Train and evaluate each model
for name, model in models.items():
    print(f"Training {name}...")
    model.fit(x_train_resampled, y_train_resampled)
    print("Evaluating...")
   
    # Make predictions
    y_pred = model.predict(x_test)
    
    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    # Print results
    print(f"{name} Results:")
    print(f"Accuracy Score: {accuracy}")
    print(f"Precision Score: {precision}")
    print(f"Recall Score: {recall}")
    print(f"F1 Score: {f1}")
    print("---------------------------")
# Out:
# Training Logistic Regression...
# Evaluating...
# Logistic Regression Results:
# Accuracy Score: 0.8099762470308789
# Precision Score: 0.8533834586466166
# Recall Score: 0.8470149253731343
# F1 Score: 0.8501872659176029
# ---------------------------
# Training Decision Tree Classifier...
# Evaluating...
# Decision Tree Classifier Results:
# Accuracy Score: 0.8836104513064132
# Precision Score: 0.932806324110672
# Recall Score: 0.8805970149253731
# F1 Score: 0.9059500959692898
# ---------------------------
# Training Random Forest Classifier...
# Evaluating...
# Random Forest Classifier Results:
# Accuracy Score: 0.9334916864608076
# Precision Score: 0.9411764705882353
# Recall Score: 0.9552238805970149
# F1 Score: 0.9481481481481482
# ---------------------------
